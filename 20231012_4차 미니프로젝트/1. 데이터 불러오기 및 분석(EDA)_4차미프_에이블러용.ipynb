# %% [markdown]
# # 안녕하세요^^
# # 미니 프로젝트에 오신 여러분을 환영합니다.
#
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.

# %% [markdown]
# ## 기본 데이터
#
# [기본 데이터]
# * 서울시 특정구 특정동의 생활인구 데이터입니다.
# * data2017.csv
# * data2018.csv
# * data2019.csv
# * data2020.csv
# * data2021.csv
# * data2022.csv
#
#
# * 2017~2021년은 데이터 전부(train data), 2022년은 1~6월(test data)까지 제공합니다.
#
# [변수 소개]
# * index : 날짜
#
# * 시간대 : 0 ~ 23
#
# * 총 생활 인구 수 : 생활 인구 합계
#
# * 각 성별, 연령대 별 생활 인구수

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'data2017.csv'파일을 'df2017' 변수에 저장하고 그 Shape을 확인하세요.
# * 아래에 'Pandas'를 Import하고 'data2017.csv'파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
df17 = pd.read_csv('data2017.csv',)
df17.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  31535.2200      1945.4402         566.4588
# 1  20170101      1  31188.9174      1930.4766         562.1018
# 2  20170101      2  31240.4974      1921.1864         559.3965
# 3  20170101      3  31442.4314      1946.4476         566.7525
# 4  20170101      4  31922.7751      1953.7713         568.8845
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         631.5581         991.9184        1297.1287        1223.1529
# 1         625.2151        1030.6281        1307.7381        1183.0956
# 2         658.7463        1058.7082        1311.9591        1186.2600
# 3         649.0804        1057.9119        1324.2638        1202.1250
# 4         623.2087        1063.2557        1342.9146        1209.2680
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1552.9448  ...        1157.6661        1107.6781        1282.9235
# 1        1491.5827  ...        1120.0051        1102.5198        1271.8997
# 2        1537.3732  ...        1103.1547        1112.4579        1282.9366
# 3        1521.2732  ...        1116.2165        1102.0668        1260.8472
# 4        1556.0675  ...        1187.5457        1120.2232        1281.2738
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1029.4360         998.0414         874.5643        1162.1547
# 1        1027.2574        1038.7528         857.9100        1149.7532
# 2        1027.8901        1020.0177         853.3890        1193.4472
# 3        1007.6650        1042.9554         896.0038        1163.0355
# 4        1064.0655        1045.2130         895.8336        1191.7017
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1053.0477         964.3940     2025.4819
# 1        1042.7411         919.0115     2062.2422
# 2        1011.2073         889.9325     1960.1236
# 3        1056.6428         891.9177     2060.1872
# 4        1045.3362         874.4984     2038.6212
#
# [5 rows x 31 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 데이터 프레임의 Shape을 확인합니다.
df17.shape
# Out:
# (8760, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 2. 추가 데이터 불러오기

# %% [markdown]
# #### [실습문제2] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2018.csv' ~ 'data2021.csv'를 df18 ~ df21로 각각 불러오고, 이미 불러와 있던 df17을 포함하여 'df_total'로 합쳐보세요. 그리고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df18 = pd.read_csv('data2018.csv')
df19 = pd.read_csv('data2019.csv')
df20 = pd.read_csv('data2020.csv')
df21 = pd.read_csv('data2021.csv')
df_total = pd.concat([df17,df18,df19,df20,df21])

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.head())
display(df_total.tail())
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  31535.2200      1945.4402         566.4588
# 1  20170101      1  31188.9174      1930.4766         562.1018
# 2  20170101      2  31240.4974      1921.1864         559.3965
# 3  20170101      3  31442.4314      1946.4476         566.7525
# 4  20170101      4  31922.7751      1953.7713         568.8845
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         631.5581         991.9184        1297.1287        1223.1529
# 1         625.2151        1030.6281        1307.7381        1183.0956
# 2         658.7463        1058.7082        1311.9591        1186.2600
# 3         649.0804        1057.9119        1324.2638        1202.1250
# 4         623.2087        1063.2557        1342.9146        1209.2680
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1552.9448  ...        1157.6661        1107.6781        1282.9235
# 1        1491.5827  ...        1120.0051        1102.5198        1271.8997
# 2        1537.3732  ...        1103.1547        1112.4579        1282.9366
# 3        1521.2732  ...        1116.2165        1102.0668        1260.8472
# 4        1556.0675  ...        1187.5457        1120.2232        1281.2738
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1029.4360         998.0414         874.5643        1162.1547
# 1        1027.2574        1038.7528         857.9100        1149.7532
# 2        1027.8901        1020.0177         853.3890        1193.4472
# 3        1007.6650        1042.9554         896.0038        1163.0355
# 4        1064.0655        1045.2130         895.8336        1191.7017
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1053.0477         964.3940     2025.4819
# 1        1042.7411         919.0115     2062.2422
# 2        1011.2073         889.9325     1960.1236
# 3        1056.6428         891.9177     2060.1872
# 4        1045.3362         874.4984     2038.6212
#
# [5 rows x 31 columns]
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 8755  20211231     19  33060.4555      1858.2611         541.0746
# 8756  20211231     20  32360.1898      2093.8808         609.6807
# 8757  20211231     21  31417.3991      1983.6728         577.5909
# 8758  20211231     22  30763.0563      2028.3314         590.5941
# 8759  20211231     23  30404.2740      1903.8825         554.3582
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 8755         605.9080         781.6602        1342.6763        1435.1080
# 8756         612.5326         768.8351        1323.7124        1479.1382
# 8757         639.2174         779.6693        1187.6783        1375.6785
# 8758         654.0295         790.1638        1133.6311        1362.0266
# 8759         615.0753         772.8499        1136.6157        1295.0434
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 8755        1678.8904  ...        1415.9734        1513.1706        1521.8562
# 8756        1654.5005  ...        1311.7764        1431.5813        1461.8649
# 8757        1600.9946  ...        1186.6502        1348.7581        1407.1924
# 8758        1548.7366  ...        1108.3915        1260.6435        1391.1649
# 8759        1549.1984  ...         993.5635        1166.8245        1428.1257
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 8755        1277.9546        1279.9036         977.2774        1091.7204
# 8756        1294.2541        1232.4805         918.4935        1062.8069
# 8757        1223.4195        1205.9346         908.4537         999.7321
# 8758        1213.3359        1110.3310         863.0019         991.0451
# 8759        1239.5283        1186.8895         805.3827         986.6660
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 8755         942.1525         789.2094     1705.8216
# 8756         894.8617         792.1748     1726.3071
# 8757         874.9000         770.3955     1674.6047
# 8758         848.4622         753.9750     1727.0258
# 8759         872.1547         734.2503     1759.0664
#
# [5 rows x 31 columns]

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_total.shape
# Out:
# (43512, 31)

# %% [markdown]
# #### [실습문제3] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data2022.csv'를 df_test로 불러오고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test = pd.read_csv('data2022.csv')
df_test.head()
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20220101      0  30509.7386      1884.2082         548.6298
# 1  20220101      1  30759.5067      1918.5330         558.6242
# 2  20220101      2  31048.8787      2068.1943         602.2013
# 3  20220101      3  31076.1092      1951.7702         568.3016
# 4  20220101      4  31714.9309      2058.5797         599.4019
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         635.1617         816.1686        1140.0136        1310.3109
# 1         665.6793         822.6910        1159.5614        1293.1350
# 2         680.8294         819.7141        1164.5819        1331.9311
# 3         690.9847         804.2219        1180.7028        1336.8848
# 4         708.3313         847.9704        1168.0681        1355.7735
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1528.2100  ...        1034.3335        1210.2650        1427.1433
# 1        1542.7586  ...        1072.8086        1193.7476        1403.5719
# 2        1537.8207  ...        1090.9845        1208.3281        1410.2452
# 3        1542.4681  ...        1104.3879        1224.9349        1414.4162
# 4        1586.0121  ...        1152.1235        1269.6214        1442.1163
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1218.2473        1167.4485         823.9020        1032.1651
# 1        1248.7765        1180.9186         838.5323         998.1091
# 2        1268.6557        1197.7707         840.6799        1026.5402
# 3        1275.0993        1207.1428         856.1711        1042.1205
# 4        1296.6590        1206.5972         875.1503        1052.5656
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         872.8850         767.0226     1737.1551
# 1         862.3041         776.7908     1753.0597
# 2         882.2846         772.8478     1757.8801
# 3         891.6092         785.1560     1747.8953
# 4         877.6836         795.0789     1760.4713
#
# [5 rows x 31 columns]

# %%
# 데이터 프레임의 Shape을 확인합니다.
df_test.shape
# Out:
# (4344, 31)

# %% [markdown]
# #### [실습문제4] 데이터 확인
# * df_total와 df_test 데이터를 head, tail. describe, info 등을 활용하여 확인하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
display(df_total.head(10))
display(df_total.tail(10))
# Out:
#       기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20170101      0  31535.2200      1945.4402         566.4588
# 1  20170101      1  31188.9174      1930.4766         562.1018
# 2  20170101      2  31240.4974      1921.1864         559.3965
# 3  20170101      3  31442.4314      1946.4476         566.7525
# 4  20170101      4  31922.7751      1953.7713         568.8845
# 5  20170101      5  33633.7304      2122.3666         617.9749
# 6  20170101      6  34876.8006      2165.5627         630.5523
# 7  20170101      7  35358.9775      2227.9843         648.7271
# 8  20170101      8  36038.7688      2394.6462         697.2551
# 9  20170101      9  37353.1794      2476.5581         721.1057
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         631.5581         991.9184        1297.1287        1223.1529
# 1         625.2151        1030.6281        1307.7381        1183.0956
# 2         658.7463        1058.7082        1311.9591        1186.2600
# 3         649.0804        1057.9119        1324.2638        1202.1250
# 4         623.2087        1063.2557        1342.9146        1209.2680
# 5         660.4000        1102.3333        1385.9335        1293.1982
# 6         685.8867        1090.8849        1463.2645        1381.0019
# 7         705.4595        1110.7236        1403.0821        1441.6585
# 8         720.5684        1182.1092        1461.3109        1413.8392
# 9         763.1041        1323.6375        1523.8240        1508.1075
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1552.9448  ...        1157.6661        1107.6781        1282.9235
# 1        1491.5827  ...        1120.0051        1102.5198        1271.8997
# 2        1537.3732  ...        1103.1547        1112.4579        1282.9366
# 3        1521.2732  ...        1116.2165        1102.0668        1260.8472
# 4        1556.0675  ...        1187.5457        1120.2232        1281.2738
# 5        1626.5706  ...        1335.3663        1191.1654        1361.7373
# 6        1657.1714  ...        1432.2406        1247.4796        1414.0056
# 7        1736.6020  ...        1460.6183        1282.2150        1446.2129
# 8        1679.3359  ...        1515.8488        1339.9149        1534.0010
# 9        1752.3785  ...        1625.4570        1461.6038        1594.1781
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 8750        1001.3863         757.6282     1648.3022
# 8751         957.1546         769.3613     1784.9523
# 8752         999.7934         772.0839     1741.8172
# 8753         994.8698         822.6193     1713.4583
# 8754        1023.7986         770.3468     1731.0993
# 8755         942.1525         789.2094     1705.8216
# 8756         894.8617         792.1748     1726.3071
# 8757         874.9000         770.3955     1674.6047
# 8758         848.4622         753.9750     1727.0258
# 8759         872.1547         734.2503     1759.0664
#
# [10 rows x 31 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
print(df_total.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43512 entries, 0 to 8759
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  int64
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
#  16  남자70세이상생활인구수     43512 non-null  float64
#  17  여자0세부터9세생활인구수    43512 non-null  float64
#  18  여자10세부터14세생활인구수  43512 non-null  float64
#  19  여자15세부터19세생활인구수  43512 non-null  float64
#  20  여자20세부터24세생활인구수  43512 non-null  float64
#  21  여자25세부터29세생활인구수  43512 non-null  float64
#  22  여자30세부터34세생활인구수  43512 non-null  float64
#  23  여자35세부터39세생활인구수  43512 non-null  float64
#  24  여자40세부터44세생활인구수  43512 non-null  float64
#  25  여자45세부터49세생활인구수  43512 non-null  float64
#  26  여자50세부터54세생활인구수  43512 non-null  float64
#  27  여자55세부터59세생활인구수  43512 non-null  float64
#  28  여자60세부터64세생활인구수  43512 non-null  float64
#  29  여자65세부터69세생활인구수  43512 non-null  float64
#  30  여자70세이상생활인구수     43512 non-null  float64
# dtypes: float64(29), int64(2)
# memory usage: 10.6 MB
# None

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total.describe().T
# Out:
#                    count          mean           std           min  \
# 기준일ID            43512.0  2.019067e+07  14194.989803  2.017010e+07
# 시간대구분            43512.0  1.150000e+01      6.922266  0.000000e+00
# 총생활인구수           43512.0  3.739066e+04   4310.755449  2.701157e+04
# 남자0세부터9세생활인구수    43512.0  2.148116e+03    300.500034  1.256223e+03
# 남자10세부터14세생활인구수  43512.0  6.254725e+02     87.497350  3.657778e+02
# 남자15세부터19세생활인구수  43512.0  7.803027e+02    133.564721  4.337626e+02
# 남자20세부터24세생활인구수  43512.0  1.281098e+03    254.313828  6.384080e+02
# 남자25세부터29세생활인구수  43512.0  1.527966e+03    243.519957  9.449047e+02
# 남자30세부터34세생활인구수  43512.0  1.651546e+03    258.969396  1.032076e+03
# 남자35세부터39세생활인구수  43512.0  1.954198e+03    268.571940  1.292427e+03
# 남자40세부터44세생활인구수  43512.0  1.702120e+03    255.984178  9.567808e+02
# 남자45세부터49세생활인구수  43512.0  1.671585e+03    267.275107  9.604186e+02
# 남자50세부터54세생활인구수  43512.0  1.374311e+03    248.475492  8.469045e+02
# 남자55세부터59세생활인구수  43512.0  1.416181e+03    234.649360  9.196407e+02
# 남자60세부터64세생활인구수  43512.0  1.107431e+03    157.568387  7.486774e+02
# 남자65세부터69세생활인구수  43512.0  7.195498e+02     97.000656  4.926888e+02
# 남자70세이상생활인구수     43512.0  1.363120e+03    130.878516  9.680914e+02
# 여자0세부터9세생활인구수    43512.0  2.027226e+03    354.281664  1.168129e+03
# 여자10세부터14세생활인구수  43512.0  5.443738e+02     95.135733  3.136794e+02
# 여자15세부터19세생활인구수  43512.0  6.456542e+02    128.757216  2.873356e+02
# 여자20세부터24세생활인구수  43512.0  1.231510e+03    207.461250  6.928497e+02
# 여자25세부터29세생활인구수  43512.0  1.584695e+03    253.507304  9.031067e+02
# 여자30세부터34세생활인구수  43512.0  1.564601e+03    219.687578  9.095705e+02
# 여자35세부터39세생활인구수  43512.0  1.674194e+03    191.108060  1.025843e+03
# 여자40세부터44세생활인구수  43512.0  1.350005e+03    146.287736  8.273803e+02
# 여자45세부터49세생활인구수  43512.0  1.270864e+03    142.600281  8.105596e+02
# 여자50세부터54세생활인구수  43512.0  1.096356e+03    141.477103  7.220096e+02
# 여자55세부터59세생활인구수  43512.0  1.240732e+03    161.394866  8.264695e+02
# 여자60세부터64세생활인구수  43512.0  1.097079e+03    154.086172  7.534347e+02
# 여자65세부터69세생활인구수  43512.0  8.021239e+02    103.382497  5.489780e+02
# 여자70세이상생활인구수     43512.0  1.938250e+03    261.300489  1.344929e+03
#
#                           25%           50%           75%           max
# 기준일ID            2.018033e+07  2.019063e+07  2.020100e+07  2.021123e+07
# 시간대구분            5.750000e+00  1.150000e+01  1.725000e+01  2.300000e+01
# 총생활인구수           3.387574e+04  3.689478e+04  4.033789e+04  5.516067e+04
# 남자0세부터9세생활인구수    1.949557e+03  2.110842e+03  2.319440e+03  5.732895e+03
# 남자10세부터14세생활인구수  5.676572e+02  6.146192e+02  6.753569e+02  1.669262e+03
# 남자15세부터19세생활인구수  6.971316e+02  7.737252e+02  8.475016e+02  2.552667e+03
# 남자20세부터24세생활인구수  1.098306e+03  1.286790e+03  1.459180e+03  2.254272e+03
# 남자25세부터29세생활인구수  1.356053e+03  1.476643e+03  1.666845e+03  2.602287e+03
# 남자30세부터34세생활인구수  1.468659e+03  1.599619e+03  1.801818e+03  2.889718e+03
# 남자35세부터39세생활인구수  1.742719e+03  1.914347e+03  2.131280e+03  3.113842e+03
# 남자40세부터44세생활인구수  1.506319e+03  1.671878e+03  1.868416e+03  2.769306e+03
# 남자45세부터49세생활인구수  1.476563e+03  1.604709e+03  1.861059e+03  2.689268e+03
# 남자50세부터54세생활인구수  1.172716e+03  1.328002e+03  1.556628e+03  2.156502e+03
# 남자55세부터59세생활인구수  1.227168e+03  1.387861e+03  1.571987e+03  2.189777e+03
# 남자60세부터64세생활인구수  9.830067e+02  1.081004e+03  1.215026e+03  1.665886e+03
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1218.2473        1167.4485         823.9020        1032.1651
# 1        1248.7765        1180.9186         838.5323         998.1091
# 2        1268.6557        1197.7707         840.6799        1026.5402
# 3        1275.0993        1207.1428         856.1711        1042.1205
# 4        1296.6590        1206.5972         875.1503        1052.5656
# 5        1352.9555        1298.5918         946.2756        1104.0372
# 6        1441.0238        1378.7674        1039.5649        1115.8314
# 7        1396.7493        1340.8060        1030.6455        1137.1065
# 8        1370.0062        1337.0045        1004.2041        1099.7680
# 9        1395.2084        1250.0378         963.0888        1112.2464
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0         872.8850         767.0226     1737.1551
# 1         862.3041         776.7908     1753.0597
# 2         882.2846         772.8478     1757.8801
# 3         891.6092         785.1560     1747.8953
# 4         877.6836         795.0789     1760.4713
# 5         893.9283         794.8634     1754.5386
# 6         887.4510         792.5001     1783.0421
# 7         914.0524         805.7049     1682.9957
# 8         892.5562         810.2563     1658.9864
# 9         863.2535         778.4274     1710.4530
#
# [10 rows x 31 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test.tail()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 4339  20220630     19  32969.6040      2108.4754         613.9301
# 4340  20220630     20  31014.6597      2017.9104         587.5599
# 4341  20220630     21  30923.2923      2083.7634         606.7347
# 4342  20220630     22  30509.5463      2186.0950         636.5307
# 4343  20220630     23  31184.8763      2179.2547         634.5390
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 4339         565.6419         904.1955        1338.8420        1416.2874
# 4340         542.7330         826.7983        1210.9392        1313.6926
# 4341         544.7149         813.5115        1175.5524        1279.7073
# 4342         573.6676         755.8347        1156.8269        1230.5487
# 4343         580.9860         711.6332        1212.8320        1308.7377
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 4339        1785.9297  ...        1317.1130        1414.8528        1587.0943
# 4340        1596.4043  ...        1239.8245        1345.4435        1499.0060
# 4341        1659.6803  ...        1103.4450        1321.0237        1434.9698
# 4342        1605.8491  ...        1052.4724        1302.8045        1413.5208
# 4343        1703.1838  ...        1077.5920        1255.1600        1440.3530
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 4339        1315.6209        1221.7289         952.5630        1094.5123
# 4340        1255.8520        1134.0779         906.4051        1016.0333
# 4341        1236.1779        1113.2840         907.1416        1002.7494
# 4342        1221.4595        1160.3239         879.1828         949.2953
# 4343        1308.9829        1200.4453         840.6338        1001.2561
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 4339         932.6297         694.0737     1687.9623
# 4340         829.0177         693.8136     1679.0869
# 4341         835.7204         682.2879     1672.6951
# 4342         821.7916         666.9312     1666.6319
# 4343         851.5886         716.4634     1761.5731
#
# [5 rows x 31 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344 entries, 0 to 4343
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            4344 non-null   int64
#  1   시간대구분            4344 non-null   int64
#  2   총생활인구수           4344 non-null   float64
#  3   남자0세부터9세생활인구수    4344 non-null   float64
#  4   남자10세부터14세생활인구수  4344 non-null   float64
#  5   남자15세부터19세생활인구수  4344 non-null   float64
#  6   남자20세부터24세생활인구수  4344 non-null   float64
#  7   남자25세부터29세생활인구수  4344 non-null   float64
#  8   남자30세부터34세생활인구수  4344 non-null   float64
#  9   남자35세부터39세생활인구수  4344 non-null   float64
#  10  남자40세부터44세생활인구수  4344 non-null   float64
#  11  남자45세부터49세생활인구수  4344 non-null   float64
#  12  남자50세부터54세생활인구수  4344 non-null   float64
#  13  남자55세부터59세생활인구수  4344 non-null   float64
#  14  남자60세부터64세생활인구수  4344 non-null   float64
#  15  남자65세부터69세생활인구수  4344 non-null   float64
#  16  남자70세이상생활인구수     4344 non-null   float64
#  17  여자0세부터9세생활인구수    4344 non-null   float64
#  18  여자10세부터14세생활인구수  4344 non-null   float64
#  19  여자15세부터19세생활인구수  4344 non-null   float64
#  20  여자20세부터24세생활인구수  4344 non-null   float64
#  21  여자25세부터29세생활인구수  4344 non-null   float64
#  22  여자30세부터34세생활인구수  4344 non-null   float64
#  23  여자35세부터39세생활인구수  4344 non-null   float64
#  24  여자40세부터44세생활인구수  4344 non-null   float64
#  25  여자45세부터49세생활인구수  4344 non-null   float64
#  26  여자50세부터54세생활인구수  4344 non-null   float64
#  27  여자55세부터59세생활인구수  4344 non-null   float64
#  28  여자60세부터64세생활인구수  4344 non-null   float64
#  29  여자65세부터69세생활인구수  4344 non-null   float64
#  30  여자70세이상생활인구수     4344 non-null   float64
# dtypes: float64(29), int64(2)
# memory usage: 1.0 MB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test.describe().T
# Out:
#                   count          mean          std           min  \
# 기준일ID            4344.0  2.022037e+07   171.298728  2.022010e+07
# 시간대구분            4344.0  1.150000e+01     6.922983  0.000000e+00
# 총생활인구수           4344.0  3.600392e+04  3553.140560  2.816869e+04
# 남자0세부터9세생활인구수    4344.0  2.325551e+03   309.575554  1.535927e+03
# 남자10세부터14세생활인구수  4344.0  6.771365e+02    90.139893  4.472197e+02
# 남자15세부터19세생활인구수  4344.0  6.497756e+02   110.616291  3.576542e+02
# 남자20세부터24세생활인구수  4344.0  8.869343e+02   105.890912  5.897504e+02
# 남자25세부터29세생활인구수  4344.0  1.310852e+03   113.693016  9.135917e+02
# 남자30세부터34세생활인구수  4344.0  1.600397e+03   205.623073  1.158487e+03
# 남자35세부터39세생활인구수  4344.0  1.854338e+03   223.965976  1.399757e+03
# 남자40세부터44세생활인구수  4344.0  1.825350e+03   210.863611  1.309398e+03
# 남자45세부터49세생활인구수  4344.0  1.722502e+03   206.231112  1.192090e+03
# 남자50세부터54세생활인구수  4344.0  1.339460e+03   218.258864  9.449805e+02
# 남자55세부터59세생활인구수  4344.0  1.314842e+03   206.028290  9.237584e+02
# 남자60세부터64세생활인구수  4344.0  1.049580e+03   113.249250  7.794191e+02
# 남자65세부터69세생활인구수  4344.0  7.140819e+02    59.355423  5.694102e+02
# 남자70세이상생활인구수     4344.0  1.216681e+03    78.136203  9.629651e+02
# 여자0세부터9세생활인구수    4344.0  1.979077e+03   341.292984  1.347278e+03
# 여자10세부터14세생활인구수  4344.0  5.314443e+02    91.647866  3.617863e+02
# 여자15세부터19세생활인구수  4344.0  6.054619e+02   107.101233  3.129078e+02
# 여자20세부터24세생활인구수  4344.0  1.122424e+03   143.771592  6.971073e+02
# 여자25세부터29세생활인구수  4344.0  1.412587e+03   216.052116  8.343105e+02
# 여자30세부터34세생활인구수  4344.0  1.538280e+03   208.053558  1.072935e+03
# 여자35세부터39세생활인구수  4344.0  1.727867e+03   198.264255  1.219019e+03
# 여자55세부터59세생활인구수  1.073275e+03  1.162911e+03  1.257175e+03  2.159587e+03
# 여자60세부터64세생활인구수  8.942286e+02  9.543672e+02  1.024499e+03  1.662765e+03
# 여자65세부터69세생활인구수  7.304463e+02  7.570645e+02  7.899566e+02  1.303252e+03
# 여자70세이상생활인구수     1.759034e+03  1.817630e+03  1.891056e+03  2.598035e+03

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# ---

# %% [markdown]
# # 3. 데이터 분석하기
# ## EDA for Feature Engineering
#
# * EDA는 명확한 목적하에, 반드시 workflow에 도움이 되는 결과를 도출해야 함.
# * EDA를 검색해봐도 좋음.
#
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
sns.set(font="NanumBarunGothic",#"NanumGothicCoding",
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제5] 데이터 형태 변경하기
# * df_total, df_test의 index를 리셋 하고, ['기준일ID']에 to_datetime 함수를 사용하여 데이터 형태를 변경하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_total.reset_index(drop=True, inplace=True)
df_total['기준일ID'] = df_total['기준일ID'].astype('str')
df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format='%Y%m%d')
print(df_total.info())
display(df_total.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43512 entries, 0 to 43511
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  datetime64[ns]
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
#  16  남자70세이상생활인구수     43512 non-null  float64
#  17  여자0세부터9세생활인구수    43512 non-null  float64
#  18  여자10세부터14세생활인구수  43512 non-null  float64
#  19  여자15세부터19세생활인구수  43512 non-null  float64
#  20  여자20세부터24세생활인구수  43512 non-null  float64
#  21  여자25세부터29세생활인구수  43512 non-null  float64
#  22  여자30세부터34세생활인구수  43512 non-null  float64
#  23  여자35세부터39세생활인구수  43512 non-null  float64
#  24  여자40세부터44세생활인구수  43512 non-null  float64
#  25  여자45세부터49세생활인구수  43512 non-null  float64
#  26  여자50세부터54세생활인구수  43512 non-null  float64
#  27  여자55세부터59세생활인구수  43512 non-null  float64
#  28  여자60세부터64세생활인구수  43512 non-null  float64
#  29  여자65세부터69세생활인구수  43512 non-null  float64
#  30  여자70세이상생활인구수     43512 non-null  float64
# dtypes: datetime64[ns](1), float64(29), int64(1)
# memory usage: 10.3 MB
# None
#        기준일ID  시간대구분    총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2017-01-01      0  31535.22      1945.4402         566.4588
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         631.5581         991.9184        1297.1287        1223.1529
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0        1552.9448  ...        1157.6661        1107.6781        1282.9235
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0         1029.436         998.0414         874.5643        1162.1547
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0        1053.0477          964.394     2025.4819
#
# [1 rows x 31 columns]

# %%
df_total.tail(1)
# Out:
#            기준일ID  시간대구분     총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 43511 2021-12-31     23  30404.274      1903.8825         554.3582
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 43511         615.0753         772.8499        1136.6157        1295.0434
#
#        남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 43511        1549.1984  ...         993.5635        1166.8245
#
#        여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# 43511        1428.1257        1239.5283        1186.8895         805.3827
#
#        여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 43511          986.666         872.1547         734.2503     1759.0664
#
# [1 rows x 31 columns]

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df_test.reset_index(drop=True, inplace=True)
df_test['기준일ID'] = df_test['기준일ID'].astype('str')
df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'], format='%Y%m%d')
print(df_test.info())
display(df_test.head(1))
display(df_test.tail(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344 entries, 0 to 4343
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            4344 non-null   datetime64[ns]
#  1   시간대구분            4344 non-null   int64
#  2   총생활인구수           4344 non-null   float64
#  3   남자0세부터9세생활인구수    4344 non-null   float64
#  4   남자10세부터14세생활인구수  4344 non-null   float64
#  5   남자15세부터19세생활인구수  4344 non-null   float64
#  6   남자20세부터24세생활인구수  4344 non-null   float64
#  7   남자25세부터29세생활인구수  4344 non-null   float64
#  8   남자30세부터34세생활인구수  4344 non-null   float64
#  9   남자35세부터39세생활인구수  4344 non-null   float64
#  10  남자40세부터44세생활인구수  4344 non-null   float64
#  11  남자45세부터49세생활인구수  4344 non-null   float64
#  12  남자50세부터54세생활인구수  4344 non-null   float64
#  13  남자55세부터59세생활인구수  4344 non-null   float64
#  14  남자60세부터64세생활인구수  4344 non-null   float64
#  15  남자65세부터69세생활인구수  4344 non-null   float64
#  16  남자70세이상생활인구수     4344 non-null   float64
#  17  여자0세부터9세생활인구수    4344 non-null   float64
#  18  여자10세부터14세생활인구수  4344 non-null   float64
#  19  여자15세부터19세생활인구수  4344 non-null   float64
#  20  여자20세부터24세생활인구수  4344 non-null   float64
#  21  여자25세부터29세생활인구수  4344 non-null   float64
#  22  여자30세부터34세생활인구수  4344 non-null   float64
#  23  여자35세부터39세생활인구수  4344 non-null   float64
#  24  여자40세부터44세생활인구수  4344 non-null   float64
#  25  여자45세부터49세생활인구수  4344 non-null   float64
#  26  여자50세부터54세생활인구수  4344 non-null   float64
#  27  여자55세부터59세생활인구수  4344 non-null   float64
#  28  여자60세부터64세생활인구수  4344 non-null   float64
#  29  여자65세부터69세생활인구수  4344 non-null   float64
#  30  여자70세이상생활인구수     4344 non-null   float64
# dtypes: datetime64[ns](1), float64(29), int64(1)
# memory usage: 1.0 MB
# None
#        기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0 2022-01-01      0  30509.7386      1884.2082         548.6298
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0         635.1617         816.1686        1140.0136        1310.3109
#
#    남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0          1528.21  ...        1034.3335         1210.265        1427.1433
#
#    여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 0        1218.2473        1167.4485          823.902        1032.1651
#
#    여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 0          872.885         767.0226     1737.1551
#
# [1 rows x 31 columns]
#           기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 4343 2022-06-30     23  31184.8763      2179.2547          634.539
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 4343          580.986         711.6332         1212.832        1308.7377
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 4343        1703.1838  ...         1077.592          1255.16         1440.353
#
#       여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  여자55세부터59세생활인구수  \
# 4343        1308.9829        1200.4453         840.6338        1001.2561
#
#       여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 4343         851.5886         716.4634     1761.5731
#
# [1 rows x 31 columns]

# %% [markdown]
# #### [실습문제6] 데이터 분포 알아보기
# * df_total 및 df_test의 '총생활인구수' 변수를 기준으로 각종 Chart를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(10,6))
sns.lineplot(x='기준일ID', y='총생활인구수', data=df_total)
plt.show()

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
temp = df_total.groupby('시간대구분', as_index=False)['총생활인구수'].mean()
sns.barplot(x='시간대구분', y='총생활인구수', data=temp)
plt.show()

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
sns.scatterplot(x='남자0세부터9세생활인구수', y='총생활인구수', data=df_total)
# Out:
# <Axes: xlabel='남자0세부터9세생활인구수', ylabel='총생활인구수'>

# %%
df_total.tail()
# Out:
#            기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 43507 2021-12-31     19  33060.4555      1858.2611         541.0746
# 43508 2021-12-31     20  32360.1898      2093.8808         609.6807
# 43509 2021-12-31     21  31417.3991      1983.6728         577.5909
# 43510 2021-12-31     22  30763.0563      2028.3314         590.5941
# 43511 2021-12-31     23  30404.2740      1903.8825         554.3582
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 43507         605.9080         781.6602        1342.6763        1435.1080
# 43508         612.5326         768.8351        1323.7124        1479.1382
# 43509         639.2174         779.6693        1187.6783        1375.6785
# 43510         654.0295         790.1638        1133.6311        1362.0266
# 43511         615.0753         772.8499        1136.6157        1295.0434
#
#        남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# 43507        1678.8904  ...        1415.9734        1513.1706
# 43508        1654.5005  ...        1311.7764        1431.5813
# 43509        1600.9946  ...        1186.6502        1348.7581
# 43510        1548.7366  ...        1108.3915        1260.6435
# 43511        1549.1984  ...         993.5635        1166.8245
#
#        여자35세부터39세생활인구수  여자40세부터44세생활인구수  여자45세부터49세생활인구수  여자50세부터54세생활인구수  \
# 43507        1521.8562        1277.9546        1279.9036         977.2774
# 43508        1461.8649        1294.2541        1232.4805         918.4935
# 43509        1407.1924        1223.4195        1205.9346         908.4537
# 43510        1391.1649        1213.3359        1110.3310         863.0019
# 43511        1428.1257        1239.5283        1186.8895         805.3827
#
#        여자55세부터59세생활인구수  여자60세부터64세생활인구수  여자65세부터69세생활인구수  여자70세이상생활인구수
# 43507        1091.7204         942.1525         789.2094     1705.8216
# 43508        1062.8069         894.8617         792.1748     1726.3071
# 43509         999.7321         874.9000         770.3955     1674.6047
# 43510         991.0451         848.4622         753.9750     1727.0258
# 43511         986.6660         872.1547         734.2503     1759.0664
#
# [5 rows x 31 columns]

# %%
age_data.head()
# Out:
#        기준일ID            연령대     총생활인구수
# 0 2017-01-01  남자0세부터9세생활인구수  1945.4402
# 1 2017-01-01  남자0세부터9세생활인구수  1930.4766
# 2 2017-01-01  남자0세부터9세생활인구수  1921.1864
# 3 2017-01-01  남자0세부터9세생활인구수  1946.4476
# 4 2017-01-01  남자0세부터9세생활인구수  1953.7713

# %%
# 연령대별 생활인구 분포를 확인하기 위한 열 선택

age_columns = df_total.columns[3:-1]  # '남자0세부터9세생활인구수'부터 '여자65세부터69세생활인구수'까지



# 데이터를 '연령대'와 '총생활인구수' 열로 재구성

age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')



# 연령대별 분포를 박스플롯으로 그립니다.

plt.figure(figsize=(12, 6))

sns.boxplot(data=age_data, x='연령대', y='총생활인구수', palette='husl')

plt.title('연령대별 생활인구 분포 (상자그림)')

plt.xlabel('연령대')

plt.ylabel('총생활인구수')

plt.xticks(rotation=90)

plt.show()
# Out:
# <ipython-input-53-b3bcef7ab9b5>:9: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   age_data = pd.melt(df_total, id_vars=['기준일ID'], value_vars=age_columns, var_name='연령대', value_name='총생활인구수')

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 19년 말부터 인구수가 줄어든 이유는 코로나 때문에 이동인구가 적어?
# 2. 출산률 바닥으로 우리나라 인구수 자체가 줄고있기때문?
# 3. 활동(5~19)시간에 인구수가 늘고 아닌 시간대에는 다시 인구가 줄어든다.

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
# CSV로 저장
df_total.to_csv('total.csv', index=False, encoding='utf-8')
df_test.to_csv("test.csv", index=False, encoding='utf-8')

# %% [markdown]
# # 4. (참고) 시계열 분석 기초 (Stationary / Normality)
#
# * 아래 주어진 코드를 기반으로 해당 데이터가 정상성과 정규성을 충족 하는지 확인해봅시다

# %% [markdown]
# #### [실습문제7] 정상성 분석
# * df_total['총생활인구수'] 데이터가 정상성을 띄는지 확인해보도록 하겠습니다
#
# * 정상성을 띈다 = 시계열 데이터의 평균과 분산이 일정하다.
#     - Dickey Fuller test 를 활용합니다
#     - Stationary (p-value < 0.05)
#
# ---
#
# * 귀무가설 : H0 : 시계열 데이터에 unit root를 포함한다 : nonstatinary / 정상 시계열이 아니다.
# * 대립가설 : H1 : 시계열 데이터에 unit root를 포함하지 않는다 : 정상 시계열이다.
# ---

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(y):
    dftest = adfuller(y, autolag='AIC')
    # autolag 'AIC' : 검정 AR 모형의 차수를 자동으로 결정
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)

# %%
adf_test(df_total['총생활인구수'])
# Out:
# test statistic         -8.946524e+00
# p-value                 8.957713e-15
# # of lags               5.500000e+01
# # of observations       4.345600e+04
# Critical Value (1%)    -3.430500e+00
# Critical Value (5%)    -2.861607e+00
# Critical Value (10%)   -2.566805e+00
# dtype: float64

# %%
# test statistic 검정 통계량 - 회귀 분석의 결과로 나타나는 계수
# p-value : p-value 추정치
# # of lags : 사용된 시차의 수(used lags)
# # of observations : 분석에 사용된 자료의 수

# critical values : 1%, 5%, 10%수준에 해당되는 검정 통계량의 값

# %% [markdown]
# #### [실습문제8] 정규성 분석
# * df_total['총생활인구수'] 데이터가 정규성을 띄는지 확인해보도록 하겠습니다
#
# * 정규성을 띈다 = 데이터의 분포가 정규분포를 이룬다.
#     * Shapiro test 를 활용합니다
#     * Normality (p-value > 0.05)
#
# ---
# * 귀무가설 : H0 : 시계열 데이터가 정규성을 충족한다.
# * 대립가설 : H1 : 시계열 데이터가 정규성을 충족하지 않는다.
# ---

# %%
from scipy import stats
from scipy.stats import shapiro
shapiro_test = stats.shapiro(df_total['총생활인구수'])
shapiro_test
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.9755631685256958, pvalue=0.0)

# %%
# shapiro test의 특징 : 데이터 수가 5000을 초과 하는 경우,
#                      정규성 검정에 대한 p-value를 담보하지 못한다.(통계적 유의성이 떨어진다.)

# 시계열 데이터가 정규성을 충족하지 않습니다.

# %%
from scipy.stats import anderson
anderson(df_total['총생활인구수'])
# Out:
# AndersonResult(statistic=295.90222305037605, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=37390.66286024542, scale=4310.755448585718)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
