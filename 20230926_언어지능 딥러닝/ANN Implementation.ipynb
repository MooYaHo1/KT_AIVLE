# %%
from keras.utils import to_categorical
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense

(train_x, train_y), (test_x, test_y) = mnist.load_data()
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
train_x = train_x.reshape(train_x.shape[0], 784).astype('float32')/255.0
test_x = test_x.reshape(test_x.shape[0], 784).astype('float32')/255.0
train_y = to_categorical(train_y) # one-hot encoding
test_y = to_categorical(test_y) # one-hot encoding

model = Sequential()
model.add(Dense(1, activation='relu')) # units=256, activation='relu'
# model.add(Dense(256, activation='relu'))
# model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics='accuracy')

model.fit(train_x, train_y, epochs=5, batch_size=32, verbose=1)
_, accuracy = model.evaluate(test_x, test_y)
print('Accuracy:', accuracy)
model.summary()
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1298 - accuracy: 0.1944
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.9714 - accuracy: 0.2337
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.9085 - accuracy: 0.2588
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.8655 - accuracy: 0.2807
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.8310 - accuracy: 0.2921
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8188 - accuracy: 0.2893
# Accuracy: 0.28929999470710754
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 1)                 785
#
#  dense_18 (Dense)            (None, 10)                20
#
# =================================================================
# Total params: 805 (3.14 KB)
# Trainable params: 805 (3.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras

X = keras.Input(shape=(784,))
H = keras.layers.Dense(256, activation='relu')(X)
H = keras.layers.Dense(256, activation='relu')(H)
H = keras.layers.Dense(256, activation='relu')(H)
Y = keras.layers.Dense(10, activation='softmax')(H)

model = keras.Model(X,Y)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')
model.fit(train_x, train_y, epochs=5, batch_size=1, verbose=1)
_, accuracy = model.evaluate(test_x, test_y)
print('Accuracy:', accuracy)
model.summary()
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 198s 3ms/step - loss: 0.3033 - accuracy: 0.9207
# Epoch 2/5
# 60000/60000 [==============================] - 193s 3ms/step - loss: 0.2137 - accuracy: 0.9523
# Epoch 3/5
# 60000/60000 [==============================] - 195s 3ms/step - loss: 0.1862 - accuracy: 0.9604
# Epoch 4/5
# 60000/60000 [==============================] - 194s 3ms/step - loss: 0.1805 - accuracy: 0.9637
# Epoch 5/5
# 60000/60000 [==============================] - 198s 3ms/step - loss: 0.1683 - accuracy: 0.9657
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2314 - accuracy: 0.9607
# Accuracy: 0.9606999754905701
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 784)]             0
#
#  dense_12 (Dense)            (None, 256)               200960
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 256)               65792
#
#  dense_15 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 335114 (1.28 MB)
# Trainable params: 335114 (1.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
